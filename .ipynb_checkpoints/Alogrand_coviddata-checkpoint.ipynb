# %%
import algosdk
import math
import pandas as pd

# %%
def connect_testnet():
    algod_address_testnet = "https://testnet-algorand.api.purestake.io/ps1"
    port_test = ""
    token_test = {
       "X-API-Key": "B3SU4KcVKi94Jap2VXkK83xx38bsv95K5UZm2lab",
    }

    algod_client_test = algosdk.algod.AlgodClient(port_test, algod_address_testnet, token_test)
    return algod_client_test

# %%
def connect_mainnet():
    algod_address_mainnet = "https://mainnet-algorand.api.purestake.io/ps1"
    port = ""
    purestake_api_key = '94IaBae3fC56OeZtiWIY03TL5K4qeQjE5thyZbF0'
    token = {
        'X-API-key' : purestake_api_key,
    }

    algod_client = algosdk.algod.AlgodClient(port, algod_address_mainnet, token) # Initialize the algod client and get the basic parameters
    return algod_client

# if using my own node...
#token = "token from the file algod.token"
#server = "http://127.0.0.1" #localhost
#port = 8081 # default

# %%
def client_check(algod_client):
    try:
        status = algod_client.status()
    except Exception as e:
        print("Failed to get algod status: {}".format(e))

    if status:
        print("algod last round: {}".format(status.get("lastRound")))
        print("algod time since last round: {}".format(status.get("timeSinceLastRound")))
        print("algod catchup: {}".format(status.get("catchupTime")))
        print("algod latest version: {}".format(status.get("lastConsensusVersion")))

    # Retrieve latest block information                                                                                                                                               
    last_round = algod_client.status().get("lastRound")
    print("####################")
    block = algod_client.block_info(last_round)
    print(block)

# %%
#algod_client_test = connect_testnet()
#client_check(algod_client_test)

# %%
algod_client = connect_mainnet()
client_check(algod_client)
# Out:
# algod last round: 5766299
# algod time since last round: 2579682481
# algod catchup: 0
# algod latest version: https://github.com/algorandfoundation/specs/tree/4a9db6a25595c6fd097cf9cc137cc83027787eaa
# ####################
# {'hash': 'SOO6Y4HV552NT5YQFJGWSXDRVVFIQT5EHV3NCNVJTXQI5S76A3WA', 'previousBlockHash': 'YIDLLKDL3TMR22HDK3HUIABQTXOOZIIPEOBU2K3A7E7RW5SMZ5TQ', 'seed': 'QEAMKRNHWEHMCLYIWU5VJD4KSBT2TLHY3G5P6TP2MUVHN77DGOJA', 'proposer': 'YXGBWVBK764KGYPX6ENIADKXPWLBNAZ7MTXDZULZWGOBO2W6IAR622VSLA', 'round': 5766299, 'period': 0, 'txnRoot': 'WRS2VL2OQ5LPWBYLNBCZV3MEQ4DACSRDES6IUKHGOWYQERJRWC5A', 'reward': 113949, 'rate': 25999980, 'frac': 2720682615, 'txns': {}, 'timestamp': 1585586239, 'currentProtocol': 'https://github.com/algorandfoundation/specs/tree/4a9db6a25595c6fd097cf9cc137cc83027787eaa', 'nextProtocol': '', 'nextProtocolApprovals': 0, 'nextProtocolVoteBefore': 0, 'nextProtocolSwitchOn': 0, 'upgradePropose': '', 'upgradeApprove': False}

# %%
# For retrieving the real covid data from mainnet

address = "COVIDR5MYE757XMDCFOCS5BXFF4SKD5RTOF4RTA67F47YTJSBR5U7TKBNU"
fromRound = 5646000
maxTxnPerCall = 500 # max transactions in a batch
batchSize = 512 #Read the transactions from the blockchain in 512-block installations

params = algod_client.suggested_params()
print("total rounds:",params['lastRound'] - fromRound)
lastRound_testing = fromRound + 20*batchSize
print("testing rounds:",lastRound_testing - fromRound)
# Out:
# total rounds: 120437
# testing rounds: 10240

# %%
#  A recursive function for getting a batch of transactions, to overcome
# the limitation of maxTxnPerCall transaction per call to the API

def getTransactionBatch(fromRnd, toRnd):
    
    if (fromRnd > toRnd):# sanity check
        return []
    
    txs = algod_client.transactions_by_address(address,fromRnd,toRnd,maxTxnPerCall) # make an API call to get the transactions
    
    return txs['transactions']
    
    '''
    # If we got all the transactions, just return them
    if (fromRnd == toRnd | len(txs['transactions']) < maxTxnPerCall):
        return txs['transactions']
    
        # FIXME: If a single block contains more than maxTxnPerCall
        # transactions for the target address, the code above will return
        # only maxTxnPerCall of them.
        # This is an unlikely case, and not easy to handle. The only way to
        # handle it is to call algod.block(round#), then go over all the
        # transactions in this block and take only the ones corresponding
        # to the target address.
    
    else: # recursive call to get them in two smaller chunks
        midRnd = math.floor((fromRnd+toRnd) / 2)
        txns1 = getTransactionBatch(fromRnd, midRnd)
        txns2 = getTransactionBatch(midRnd+1, toRnd)
        # return the concatenation of the two chunks
        return txns1.concat(txns2)
    '''

# %%
#lastRound = params['lastRound']
lastRound = lastRound_testing
txns = getTransactionBatch(fromRound, lastRound) # Fetch transactions for these rounds 
print("found {} transactions".format(len(txns)))
# Out:
# found 119 transactions

# %%
def decode_node_data(transactions):
    
    cols = ['round','country_code','region_code','zip_code_3dig',
            'gender','was_quarantined','reason_quarantine','status_quarantine',
            'date_start_quarantine','date_end_quarantine',
            'is_symptomatic','fever','cough','difficulty_breathing','fatigue','sore_throat',
            'date_start_symptoms','date_end_symptoms','still_symptomatic',
            'got_medical_care',
            'type_of_care',
            'hospitalized','date_when_admitted','date_when_discharged','still_in_hospital',
            'tested','tried_to_get_tested','was_denied','date_test','results_test','location_test']
        
    trans_df = pd.DataFrame(columns = cols)
    
    for i in range(len(transactions)):
        
        tx_dict = transactions[i]
        encoded_note = tx_dict['noteb64']
        noteData = str(algosdk.encoding.base64.b64decode(encoded_note)).encode('utf8').decode('utf8')
        
        #print(noteData)
        noteData_list = noteData[7:].split('\\')
        #print("for round {}".format(tx_dict['round']))
        
        df_data_list = ['NaN']*len(cols)
        df_data_list[0] = tx_dict['round']
        
        decode_chars = ['xa1','xa2','xa3','xa6','xa7','xaa']
        clean_noteData = []
        
        for item in noteData_list:
            for char in decode_chars:
                if char in item:
                    item = item.replace(char,'')
            clean_noteData.append(item)
                    
                
        #print(noteData_list) 
        #print('\n')
        #print(clean_noteData)
        
        for j in range(0,len(clean_noteData)-1):
            if 'gc' in clean_noteData[j]:
                df_data_list[1] = clean_noteData[j+1]
            elif 'gr' in clean_noteData[j]:
                df_data_list[2] = clean_noteData[j+1]
            elif 'gzp' in clean_noteData[j]:
                df_data_list[3] = clean_noteData[j+1]
            elif 'gs' in clean_noteData[j]:
                df_data_list[4] = clean_noteData[j+1]
                
                
            elif 'qz' in clean_noteData[j]:
                if clean_noteData[j+1].replace('x','') == '01':
                    df_data_list[5] = True
                if clean_noteData[j+1].replace('x','') == '-01':
                    df_data_list[5] = False
            
            elif 'q1' in clean_noteData[j]:
                df_data_list[6] = 'due to symptoms'
            elif 'q2' in clean_noteData[j]:
                df_data_list[6] = 'voluntary'
            elif 'q3' in clean_noteData[j]:
                df_data_list[6] = 'personally required'
            elif 'q4' in clean_noteData[j]:
                df_data_list[6] = 'general quarantine'
                
            elif 'qdn' in clean_noteData[j]:
                df_data_list[7] = 'still quarantined'
                
            elif 'qds' in clean_noteData[j]:
                df_data_list[8] = clean_noteData[j+1]
            
            elif 'qde' in clean_noteData[j]:
                df_data_list[9] = clean_noteData[j+1]
                
            elif 'sz' in clean_noteData[j]:
                if clean_noteData[j+1].replace('x','') == '01':
                    df_data_list[10] = True
                if clean_noteData[j+1].replace('x','') == '-01':
                    df_data_list[10] = False
                
            elif 's1' in clean_noteData[j]:
                df_data_list[11] = True
            elif 's2' in clean_noteData[j]:
                df_data_list[12] = True
            elif 's3' in clean_noteData[j]:
                df_data_list[13] = True
            elif 's4' in clean_noteData[j]:
                df_data_list[14] = True
            elif 's5' in clean_noteData[j]:
                df_data_list[15] = True
                
            elif 'sds' in clean_noteData[j]:
                df_data_list[16] = clean_noteData[j+1]
                
            elif 'sde' in clean_noteData[j]:
                df_data_list[17] = clean_noteData[j+1]
                
            elif 'sdn' in clean_noteData[j]:
                df_data_list[18] = True
                
            elif 'mz' in clean_noteData[j]:
                if clean_noteData[j+1].replace('x','') == '01':
                    df_data_list[19] = True
                if clean_noteData[j+1].replace('x','') == '-01':
                    df_data_list[19] = False
                    
            elif 'm1' in clean_noteData[j]:
                df_data_list[20] = 'doctors office'
            elif 'm2' in clean_noteData[j]:
                df_data_list[20] = 'walk-in clinic'
            elif 'm3' in clean_noteData[j]:
                df_data_list[20] = 'virtual care'
            elif 'm4' in clean_noteData[j]:
                df_data_list[20] = 'hospital/ER'
            elif 'm5' in clean_noteData[j]:
                df_data_list[20] = 'other'
                
            elif 'mh' in clean_noteData[j]:
                if clean_noteData[j+1].replace('x','') == '01':
                    df_data_list[21] = True
                if clean_noteData[j+1].replace('x','') == '-01':
                    df_data_list[21] = False
                    
            elif 'mhs' in clean_noteData[j]:
                df_data_list[22] = clean_noteData[j+1]
            
            elif 'mhe' in clean_noteData[j]:
                df_data_list[23] = clean_noteData[j+1]
            
            elif 'mhn' in clean_noteData[j]:
                df_data_list[24] = True
            
            elif 'tz' in clean_noteData[j]:
                if clean_noteData[j+1].replace('x','') == '01':
                    df_data_list[25] = True 
                if clean_noteData[j+1].replace('x','') == '-01':
                    df_data_list[25] = False
                    
            elif 'tt' in clean_noteData[j]:
                if clean_noteData[j+1].replace('x','') == '01':
                    df_data_list[26] = True
                if clean_noteData[j+1].replace('x','') == '-01':
                    df_data_list[26] = False
                if clean_noteData[j+1].replace('x','') == '02':
                    df_data_list[27] = True
            
            elif 'td' in clean_noteData[j]:
                df_data_list[28] = clean_noteData[j+1]
                
            elif 'tr' in clean_noteData[j]:
                if clean_noteData[j+1].replace('x','') == '-01':
                    df_data_list[29] = 'negative'
                if clean_noteData[j+1].replace('x','') == '01':
                    df_data_list[29] = 'positive'
                if clean_noteData[j+1].replace('x','') == '02':
                    df_data_list[29] = 'waiting'                
                    
            elif 'tl' in clean_noteData[j]:
                if clean_noteData[j+1].replace('x','') == '01':
                    df_data_list[30] = 'Dr. Office'                
                if clean_noteData[j+1].replace('x','') == '02':
                    df_data_list[30] = 'Hospital'
                if clean_noteData[j+1].replace('x','') == '03':
                    df_data_list[30] = 'Urgent Care'                    
                if clean_noteData[j+1].replace('x','') == '04':
                    df_data_list[30] = 'Ad-hoc center'                    
                if clean_noteData[j+1].replace('x','') == '05':
                    df_data_list[30] = 'Other'
                    
            
        #print('\n')
        trans_df.loc[i] = df_data_list
    return trans_df

# %%
#dir(algosdk.encoding)

# %%
pd.set_option('display.max_rows', None)
data_df = decode_node_data(txns)
display(data_df)
# Out:
# b'\x82\xa1d\x8d\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga\x1e\xa2gc\xa2US\xa2gr\xa2MA\xa2gs\xa1m\xa3gzp\xa3024\xa2mz\xff\xa2qz\xff\xa2sz\xff\xa2tt\xff\xa2tz\xff\xa1s\xd9,2wNf79Ssv9K9bWQziaxKop4zJdk785XmxLLqZadQ4XU='
# ['xa1d', 'x8d', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga', 'x1e', 'xa2gc', 'xa2US', 'xa2gr', 'xa2MA', 'xa2gs', 'xa1m', 'xa3gzp', 'xa3024', 'xa2mz', 'xff', 'xa2qz', 'xff', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,2wNf79Ssv9K9bWQziaxKop4zJdk785XmxLLqZadQ4XU='"]
# ['d', '_t', '_v', '1', 'ga', 'gc', 'US', 'gr', 'MA', 'gs', 'm', 'gzp', '024', 'mz', 'qz', 'sz', 'tt', 'tz', 's']
#
#
# b'\x82\xa1d\x8c\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga\x1e\xa2gc\xa2US\xa2gr\xa2MD\xa2gs\xa1m\xa3gzp\xa3210\xa2mz\xff\xa2qz\xff\xa2sz\xff\xa2tz\xff\xa1s\xd9,F4fp+SZdjqR0KJ2irAobJKVPKHN4CWWHaojnUmIs+lE='
# ['xa1d', 'x8c', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga', 'x1e', 'xa2gc', 'xa2US', 'xa2gr', 'xa2MD', 'xa2gs', 'xa1m', 'xa3gzp', 'xa3210', 'xa2mz', 'xff', 'xa2qz', 'xff', 'xa2sz', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,F4fp+SZdjqR0KJ2irAobJKVPKHN4CWWHaojnUmIs+lE='"]
# ['d', '_t', '_v', '1', 'ga', 'gc', 'US', 'gr', 'MD', 'gs', 'm', 'gzp', '210', 'mz', 'qz', 'sz', 'tz', 's']
#
#
# b'\x82\xa1d\xde\x00\x10\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga\x14\xa2gc\xa2JP\xa2gr\xa213\xa2gs\xa1m\xa2mz\xff\xa2q3\xc3\xa3qde\xaa2020-02-09\xa3qds\xaa2020-01-27\xa2ql\x01\xa2qz\x01\xa2sz\xff\xa2tt\xff\xa2tz\xff\xa1s\xd9,jUnrlrDjwZyr6FDmMDTfnFtgQgXvdZF35k7g3As+5U8='
# ['xa1d', 'xde', 'x00', 'x10', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga', 'x14', 'xa2gc', 'xa2JP', 'xa2gr', 'xa213', 'xa2gs', 'xa1m', 'xa2mz', 'xff', 'xa2q3', 'xc3', 'xa3qde', 'xaa2020-02-09', 'xa3qds', 'xaa2020-01-27', 'xa2ql', 'x01', 'xa2qz', 'x01', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,jUnrlrDjwZyr6FDmMDTfnFtgQgXvdZF35k7g3As+5U8='"]
# ['d', '_t', '_v', '1', 'ga', 'gc', 'JP', 'gr', '13', 'gs', 'm', 'mz', 'q3', 'qde', 'qds', 'ql', 'qz', 'sz', 'tt', 'tz', 's']
#
#
# b'\x82\xa1d\x8c\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga7\xa2gc\xa2US\xa2gs\xa1m\xa3gzp\xa3021\xa2mz\xff\xa2qz\xff\xa2sz\xff\xa2tt\xff\xa2tz\xff\xa1s\xd9,le8yZqoOlpf1DpPgvo6IBpN3Lpbg6S48htrtjag1r7I='
# ['xa1d', 'x8c', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga7', 'xa2gc', 'xa2US', 'xa2gs', 'xa1m', 'xa3gzp', 'xa3021', 'xa2mz', 'xff', 'xa2qz', 'xff', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,le8yZqoOlpf1DpPgvo6IBpN3Lpbg6S48htrtjag1r7I='"]
# ['d', '_t', '_v', '1', 'ga7', 'gc', 'US', 'gs', 'm', 'gzp', '021', 'mz', 'qz', 'sz', 'tt', 'tz', 's']
#
#
# b'\x82\xa1d\x
 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga', 'x1e', 'xa2gc', 'xa2US', 'xa2gr', 'xa2MA', 'xa2gs', 'xa1f', 'xa3gzp', 'xa3015', 'xa2mz', 'xff', 'xa2q2', 'xc3', 'xa2q4', 'xc3', 'xa3qdn', 'xc3', 'xa3qds', 'xaa2020-03-20', 'xa2ql', 'xff', 'xa2qz', 'x01', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,KjOIWBMB0X7lyQgeME9Tb1ledgZOFFf82IXq+TtoUKE='"]
# ['d', '_t', '_v', '1', 'ga', 'gc', 'US', 'gr', 'MA', 'gs', 'f', 'gzp', '015', 'mz', 'q2', 'q4', 'qdn', 'qds', 'ql', 'qz', 'sz', 'tt', 'tz', 's']
#
#
# b'\x82\xa1d\x8d\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga<\xa2gc\xa2US\xa2gr\xa2NJ\xa2gs\xa1f\xa3gzp\xa3085\xa2mz\xff\xa2qz\xff\xa2sz\xff\xa2tt\xff\xa2tz\xff\xa1s\xd9,XHyvs8DN1WAwc4nKauv64cFS5Fk/7YOnpFzwOkCa5Rw='
# ['xa1d', 'x8d', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga<', 'xa2gc', 'xa2US', 'xa2gr', 'xa2NJ', 'xa2gs', 'xa1f', 'xa3gzp', 'xa3085', 'xa2mz', 'xff', 'xa2qz', 'xff', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,XHyvs8DN1WAwc4nKauv64cFS5Fk/7YOnpFzwOkCa5Rw='"]
# ['d', '_t', '_v', '1', 'ga<', 'gc', 'US', 'gr', 'NJ', 'gs', 'f', 'gzp', '085', 'mz', 'qz', 'sz', 'tt', 'tz', 's']
#
#
# b'\x82\xa1d\xde\x00\x11\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga\x14\xa2gc\xa2US\xa2gr\xa2MA\xa2gs\xa1m\xa3gzp\xa3012\xa2mz\xff\xa2q2\xc3\xa3qdn\xc3\xa3qds\xaa2020-03-11\xa2ql\x01\xa2qz\x01\xa2sz\xff\xa2tt\xff\xa2tz\xff\xa1s\xd9,Hbmo9dIpATPBha5tCeMocIMbtZycixRcN9i/mTxnlX4='
# ['xa1d', 'xde', 'x00', 'x11', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga', 'x14', 'xa2gc', 'xa2US', 'xa2gr', 'xa2MA', 'xa2gs', 'xa1m', 'xa3gzp', 'xa3012', 'xa2mz', 'xff', 'xa2q2', 'xc3', 'xa3qdn', 'xc3', 'xa3qds', 'xaa2020-03-11', 'xa2ql', 'x01', 'xa2qz', 'x01', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,Hbmo9dIpATPBha5tCeMocIMbtZycixRcN9i/mTxnlX4='"]
# ['d', '_t', '_v', '1', 'ga', 'gc', 'US', 'gr', 'MA', 'gs', 'm', 'gzp', '012', 'mz', 'q2', 'qdn', 'qds', 'ql', 'qz', 'sz', 'tt', 'tz', 's']
#
#
# b'\x82\xa1d\xde\x00\x17\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga(\xa2gc\xa2US\xa2gr\xa2CA\xa2gs\xa1m\xa3gzp\xa3940\xa2mz\xff\xa2q4\xc3\xa3qdn\xc3\xa3qds\xaa2020-03-13\xa2ql\x01\xa2qz\x01\xa2s2\xc3\xa2s5\xc3\xa3sdn\xc3\xa3sds\xaa2020-02-05\xa2sz\x01\xa2td\xaa2020-03-22\xa2tl\x04\xa2tr\xff\xa2tz\x01\xa1s\xd9,dfs+5V/7nT5OTf6gVW+UqUSYJjMUUqmVpb5yUs+uiD8='
# ['xa1d', 'xde', 'x00', 'x17', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga(', 'xa2gc', 'xa2US', 'xa2gr', 'xa2CA', 'xa2gs', 'xa1m', 'xa3gzp', 'xa3940', 'xa2mz', 'xff', 'xa2q4', 'xc3', 'xa3qdn', 'xc3', 'xa3qds', 'xaa2020-03-13', 'xa2ql', 'x01', 'xa2qz', 'x01', 'xa2s2', 'xc3', 'xa2s5', 'xc3', 'xa3sdn', 'xc3', 'xa3sds', 'xaa2020-02-05', 'xa2sz', 'x01', 'xa2td', 'xaa2020-03-22', 'xa2tl', 'x04', 'xa2tr', 'xff', 'xa2tz', 'x01', 'xa1s', "xd9,dfs+5V/7nT5OTf6gVW+UqUSYJjMUUqmVpb5yUs+uiD8='"]
# ['d', '_t', '_v', '1', 'ga(', 'gc', 'US', 'gr', 'CA', 'gs', 'm', 'gzp', '940', 'mz', 'q4', 'qdn', 'qds', 'ql', 'qz', 's2', 's5', 'sdn', 'sds', 'sz', 'td', 'tl', 'tr', 'tz', 's']
#
#
# b'\x82\xa1d\xde\x00\
xa2sz\xff\xa2tt\xff\xa2tz\xff\xa1s\xd9,2VbO7g5EpzUjd37XkFHc1vdLeW8HZvn4CexR0OM+Wdw='
# ['xa1d', 'xde', 'x00', 'x11', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga(', 'xa2gc', 'xa2GR', 'xa2gr', 'xa1G', 'xa2gs', 'xa1f', 'xa2mz', 'xff', 'xa2q2', 'xc3', 'xa2q4', 'xc3', 'xa3qdn', 'xc3', 'xa3qds', 'xaa2020-03-09', 'xa2ql', 'x01', 'xa2qz', 'x01', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,2VbO7g5EpzUjd37XkFHc1vdLeW8HZvn4CexR0OM+Wdw='"]
# ['d', '_t', '_v', '1', 'ga(', 'gc', 'GR', 'gr', 'G', 'gs', 'f', 'mz', 'q2', 'q4', 'qdn', 'qds', 'ql', 'qz', 'sz', 'tt', 'tz', 's']
#
#
# b'\x82\xa1d\xde\x00\x11\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga\x1e\xa2gc\xa2IT\xa2gr\xa272\xa2gs\xa1m\xa2mz\xff\xa2q2\xc3\xa2q4\xc3\xa3qdn\xc3\xa3qds\xaa2020-03-04\xa2ql\x01\xa2qz\x01\xa2sz\xff\xa2tt\xff\xa2tz\xff\xa1s\xd9,1R2wIQVZ7h4y12Qe/jgFXGetQ81EhyJz/lZQoRr4U/o='
# ['xa1d', 'xde', 'x00', 'x11', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga', 'x1e', 'xa2gc', 'xa2IT', 'xa2gr', 'xa272', 'xa2gs', 'xa1m', 'xa2mz', 'xff', 'xa2q2', 'xc3', 'xa2q4', 'xc3', 'xa3qdn', 'xc3', 'xa3qds', 'xaa2020-03-04', 'xa2ql', 'x01', 'xa2qz', 'x01', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,1R2wIQVZ7h4y12Qe/jgFXGetQ81EhyJz/lZQoRr4U/o='"]
# ['d', '_t', '_v', '1', 'ga', 'gc', 'IT', 'gr', '72', 'gs', 'm', 'mz', 'q2', 'q4', 'qdn', 'qds', 'ql', 'qz', 'sz', 'tt', 'tz', 's']
#
#
# b'\x82\xa1d\x8a\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga2\xa2gs\xa1m\xa2mz\xff\xa2qz\xff\xa2sz\xff\xa2tt\xff\xa2tz\xff\xa1s\xd9,eMfgWS04rOeVMSPaMOpsS+mc/lBbLGHwoTTBgSFq8Pc='
# ['xa1d', 'x8a', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga2', 'xa2gs', 'xa1m', 'xa2mz', 'xff', 'xa2qz', 'xff', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,eMfgWS04rOeVMSPaMOpsS+mc/lBbLGHwoTTBgSFq8Pc='"]
# ['d', '_t', '_v', '1', 'ga2', 'gs', 'm', 'mz', 'qz', 'sz', 'tt', 'tz', 's']
#
#
# b'\x82\xa1d\xde\x00\x10\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga\x1e\xa2gc\xa2ES\xa2gr\xa1M\xa2gs\xa1m\xa2mz\xff\xa2q4\xc3\xa3qdn\xc3\xa3qds\xaa2020-03-14\xa2ql\x01\xa2qz\x01\xa2sz\xff\xa2tt\xff\xa2tz\xff\xa1s\xd9,8i+7GGIL4MYfVmP0yiEL4aeImD4/IDKfdsaA0nlkhV8='
# ['xa1d', 'xde', 'x00', 'x10', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga', 'x1e', 'xa2gc', 'xa2ES', 'xa2gr', 'xa1M', 'xa2gs', 'xa1m', 'xa2mz', 'xff', 'xa2q4', 'xc3', 'xa3qdn', 'xc3', 'xa3qds', 'xaa2020-03-14', 'xa2ql', 'x01', 'xa2qz', 'x01', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,8i+7GGIL4MYfVmP0yiEL4aeImD4/IDKfdsaA0nlkhV8='"]
# ['d', '_t', '_v', '1', 'ga', 'gc', 'ES', 'gr', 'M', 'gs', 'm', 'mz', 'q4', 'qdn', 'qds', 'ql', 'qz', 'sz', 'tt', 'tz', 's']
#
#
# b'\x82\xa1d\x8c\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga(\xa2gc\xa2IT\xa2gr\xa272\xa2gs\xa1m\xa2mz\xff\xa2qz\xff\xa2sz\xff\xa2tt\xff\xa2tz\xff\xa1s\xd9,S0r5z9HY+jC1Wen1s7pPp/7aOF/xHEagHMpBuoObP8A='
# ['xa1d', 'x8c', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga(', 'xa2gc', 'xa2IT', 'xa2gr', 'xa272', 'xa2gs', 'xa1m', 'xa2mz', 'xff', 'xa2qz', 'xff', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,S0r5z9HY+jC1Wen1s7pPp/7aOF/xHEagHMpBuoObP8A='"]
# ['d', '_t', '_v', '1', 'ga(', 'gc', 'IT', 'gr', '72', 'gs', 'm', 'mz', 'qz', 'sz', 'tt', 'tz', 's']
#
#
# b'\x82\xa1d\x
 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga', 'n', 'xa2gc', 'xa2RU', 'xa2gr', 'xa3MOW', 'xa2gs', 'xa1f', 'xa2mz', 'xff', 'xa2qz', 'xff', 'xa2s1', 'xc3', 'xa2s3', 'xc3', 'xa2s4', 'xc3', 'xa3sds', 'xaa2020-03-02', 'xa2sz', 'x01', 'xa2td', 'xaa2020-03-10', 'xa2tl', 'x02', 'xa2tr', 'x01', 'xa2tz', 'x01', 'xa1s', "xd9,DVD/cworqwkXQfklFYsJgl4l8QmquOcS65PW4Xo/+uM='"]
# ['d', '_t', '_v', '1', 'ga', 'gc', 'RU', 'gr', 'MOW', 'gs', 'f', 'mz', 'qz', 's1', 's3', 's4', 'sds', 'sz', 'td', 'tl', 'tr', 'tz', 's']
#
#
# b'\x82\xa1d\xde\x00\x10\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga(\xa2gc\xa2AR\xa2gr\xa1B\xa2gs\xa1m\xa2mz\xff\xa2q4\xc3\xa3qdn\xc3\xa3qds\xaa2020-03-20\xa2ql\x01\xa2qz\x01\xa2sz\xff\xa2tt\xff\xa2tz\xff\xa1s\xd9,msnTqa/dj/v8BJWtXZHIa/8PwvchPEjqt0FpcYa7Yi4='
# ['xa1d', 'xde', 'x00', 'x10', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga(', 'xa2gc', 'xa2AR', 'xa2gr', 'xa1B', 'xa2gs', 'xa1m', 'xa2mz', 'xff', 'xa2q4', 'xc3', 'xa3qdn', 'xc3', 'xa3qds', 'xaa2020-03-20', 'xa2ql', 'x01', 'xa2qz', 'x01', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,msnTqa/dj/v8BJWtXZHIa/8PwvchPEjqt0FpcYa7Yi4='"]
# ['d', '_t', '_v', '1', 'ga(', 'gc', 'AR', 'gr', 'B', 'gs', 'm', 'mz', 'q4', 'qdn', 'qds', 'ql', 'qz', 'sz', 'tt', 'tz', 's']
#
#
# b'\x82\xa1d\xde\x00\x10\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga\x1e\xa2gc\xa2CZ\xa2gr\xa2PR\xa2gs\xa1m\xa2mz\xff\xa2q4\xc3\xa3qdn\xc3\xa3qds\xaa2020-03-11\xa2ql\x01\xa2qz\x01\xa2sz\xff\xa2tt\xff\xa2tz\xff\xa1s\xd9,1v8KXplz6bpFkB2U3X4tLG5KlvCuttSFqFif/a0Cy0M='
# ['xa1d', 'xde', 'x00', 'x10', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga', 'x1e', 'xa2gc', 'xa2CZ', 'xa2gr', 'xa2PR', 'xa2gs', 'xa1m', 'xa2mz', 'xff', 'xa2q4', 'xc3', 'xa3qdn', 'xc3', 'xa3qds', 'xaa2020-03-11', 'xa2ql', 'x01', 'xa2qz', 'x01', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,1v8KXplz6bpFkB2U3X4tLG5KlvCuttSFqFif/a0Cy0M='"]
# ['d', '_t', '_v', '1', 'ga', 'gc', 'CZ', 'gr', 'PR', 'gs', 'm', 'mz', 'q4', 'qdn', 'qds', 'ql', 'qz', 'sz', 'tt', 'tz', 's']
#
#
# b'\x82\xa1d\x8b\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga(\xa2gc\xa2US\xa2gs\xa1m\xa3gzp\xa3076\xa2mz\xff\xa2qz\xff\xa2sz\xff\xa2tz\xff\xa1s\xd9,G/Ggpsx4CENHDsOgSPKkUXjSK01dwntrjYlChYIKadA='
# ['xa1d', 'x8b', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga(', 'xa2gc', 'xa2US', 'xa2gs', 'xa1m', 'xa3gzp', 'xa3076', 'xa2mz', 'xff', 'xa2qz', 'xff', 'xa2sz', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,G/Ggpsx4CENHDsOgSPKkUXjSK01dwntrjYlChYIKadA='"]
# ['d', '_t', '_v', '1', 'ga(', 'gc', 'US', 'gs', 'm', 'gzp', '076', 'mz', 'qz', 'sz', 'tz', 's']
#
#
# b'\x82\xa1d\x8d\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga\x14\xa2gc\xa2US\xa2gr\xa2NY\xa2gs\xa1m\xa3gzp\xa3100\xa2mz\xff\xa2qz\xff\xa2sz\xff\xa2tt\xff\xa2tz\xff\xa1s\xd9,cayAwctlTBQagojY72Dow3KPRnisL44lHeBkw243KVw='
# ['xa1d', 'x8d', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga', 'x14', 'xa2gc', 'xa2US', 'xa2gr', 'xa2NY', 'xa2gs', 'xa1m', 'xa3gzp', 'xa3100', 'xa2mz', 'xff', 'xa2qz', 'xff', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,cayAwctlTBQagojY72Dow3KPRnisL44lHeBkw243KVw='"]
# ['d', '_t', '_v', '1', 'ga', 'gc', 'US', 'gr', 'NY', 'gs', 'm', 'gzp', '100', 'mz', 'qz', 'sz', 'tt', 'tz', 's']
#
#
# b'\x82\xa1d\x8c\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga7\xa2gc\xa2IL\xa2gr\xa2JM\xa2gs\xa1f\xa2mz\xff\xa2qz\xff\xa2sz\xff\xa2tt\xff\xa2tz\xff\xa1s\xd9,Uw+6+nVFWjz7KD85GdqXSnbr7wQAF5FRvVgq4QJzrh8='
# ['xa1d', 'x8c', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga7', 'xa2gc', 'xa2IL', 'xa2gr', 'xa2JM', 'xa2gs', 'xa1f', 'xa2mz', 'xff', 'xa2qz', 'xff', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,Uw+6+nVFWjz7KD85GdqXSnbr7wQAF5FRvVgq4QJzrh8='"]
# ['d', '_t', '_v', '1', 'ga7', 'gc', 'IL', 'gr', 'JM', 'gs', 'f', 'mz', 'qz', 'sz', 'tt', 'tz', 's']
#
#
# ...
#
#
# b'\x82\xa1d\xde\x00\x14\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga\x14\xa2gc\xa2US\xa2gr\xa2NY\xa2gs\xa1f\xa3gzp\xa3105\xa2mz\xff\xa2q2\xc3\xa2q4\xc3\xa3qde\xaa2020-03-23\xa3qds\xaa2020-03-06\xa2ql\x01\xa2qz\x01\xa2sz\xff\xa2td\xaa2020-03-19\xa2tl\x04\xa2tr\xff\xa2tz\x01\xa1s\xd9,82AXCosTdHLit9Y25SWEFp8f4erQLQgdaMjrpdrOIqY='
# ['xa1d', 'xde', 'x00', 'x14', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga', 'x14', 'xa2gc', 'xa2US', 'xa2gr', 'xa2NY', 'xa2gs', 'xa1f', 'xa3gzp', 'xa3105', 'xa2mz', 'xff', 'xa2q2', 'xc3', 'xa2q4', 'xc3', 'xa3qde', 'xaa2020-03-23', 'xa3qds', 'xaa2020-03-06', 'xa2ql', 'x01', 'xa2qz', 'x01', 'xa2sz', 'xff', 'xa2td', 'xaa2020-03-19', 'xa2tl', 'x04', 'xa2tr', 'xff', 'xa2tz', 'x01', 'xa1s', "xd9,82AXCosTdHLit9Y25SWEFp8f4erQLQgdaMjrpdrOIqY='"]
# ['d', '_t', '_v', '1', 'ga', 'gc', 'US', 'gr', 'NY', 'gs', 'f', 'gzp', '105', 'mz', 'q2', 'q4', 'qde', 'qds', 'ql', 'qz', 'sz', 'td', 'tl', 'tr', 'tz', 's']
#
#
# b'\x82\xa1d\x8d\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga\x14\xa2gc\xa2US\xa2gr\xa2NY\xa2gs\xa1f\xa3gzp\xa3105\xa2mz\xff\xa2qz\xff\xa2sz\xff\xa2tt\xff\xa2tz\xff\xa1s\xd9,A8fl+WuFY8KIbfEW9N69ipY6SkAO0kZslRZ4J5kZRfs='
# ['xa1d', 'x8d', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga', 'x14', 'xa2gc', 'xa2US', 'xa2gr', 'xa2NY', 'xa2gs', 'xa1f', 'xa3gzp', 'xa3105', 'xa2mz', 'xff', 'xa2qz', 'xff', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,A8fl+WuFY8KIbfEW9N69ipY6SkAO0kZslRZ4J5kZRfs='"]
# ['d', '_t', '_v', '1', 'ga', 'gc', 'US', 'gr', 'NY', 'gs', 'f', 'gzp', '105', 'mz', 'qz', 'sz', 'tt', 'tz', 's']
#
#
# b'\x82\xa1d\x8c\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga(\xa2gc\xa2AU\xa2gr\xa3ACT\xa2gs\xa1m\xa2mz\xff\xa2qz\xff\xa2sz\xff\xa2tt\xff\xa2tz\xff\xa1s\xd9,x+29V6ALeq9lafBCfpv4Lih/b0AOVHeX7zlrVPtSgdY='
# ['xa1d', 'x8c', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga(', 'xa2gc', 'xa2AU', 'xa2gr', 'xa3ACT', 'xa2gs', 'xa1m', 'xa2mz', 'xff', 'xa2qz', 'xff', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,x+29V6ALeq9lafBCfpv4Lih/b0AOVHeX7zlrVPtSgdY='"]
# ['d', '_t', '_v', '1', 'ga(', 'gc', 'AU', 'gr', 'ACT', 'gs', 'm', 'mz', 'qz', 'sz', 'tt', 'tz', 's']
#
#
# b'\x82\xa1d\xde\x00\x11\xa2_t\xa6report\xa2_v\xa11\xa7consent\xc3\xa2ga7\xa2gc\xa2US\xa2gr\xa2NY\xa2gs\xa1f\xa3gzp\xa3100\xa2mz\xff\xa2q2\xc3\xa3qdn\xc3\xa3qds\xaa2020-03-10\xa2ql\x01\xa2qz\x01\xa2sz\xff\xa2tt\xff\xa2tz\xff\xa1s\xd9,DsoQMFcEwWItoTsE+E1Tmr2b+l8StVUidkWpIXzKKK8='
# ['xa1d', 'xde', 'x00', 'x11', 'xa2_t', 'xa6report', 'xa2_v', 'xa11', 'xa7consent', 'xc3', 'xa2ga7', 'xa2gc', 'xa2US', 'xa2gr', 'xa2NY', 'xa2gs', 'xa1f', 'xa3gzp', 'xa3100', 'xa2mz', 'xff', 'xa2q2', 'xc3', 'xa3qdn', 'xc3', 'xa3qds', 'xaa2020-03-10', 'xa2ql', 'x01', 'xa2qz', 'x01', 'xa2sz', 'xff', 'xa2tt', 'xff', 'xa2tz', 'xff', 'xa1s', "xd9,DsoQMFcEwWItoTsE+E1Tmr2b+l8StVUidkWpIXzKKK8='"]
# ['d', '_t', '_v', '1', 'ga7', 'gc', 'US', 'gr', 'NY', 'gs', 'f', 'gzp', '100', 'mz', 'q2', 'qdn', 'qds', 'ql', 'qz', 'sz', 'tt', 'tz', 's']
#        round country_code region_code zip_code_3dig gender  \
# 0    5656049           US          MA           024      m
# 1    5655948           US          MD           210      m
# 2    5655902           JP          13           NaN      m
# 3    5655760           US         NaN           021      m
# 4    5655735           US          IL           618      f
# 5    5655711           US          NY           113      f
# 6    5655687           US          NY           104      m
# 7    5655586           US          CA           943      f
# 8    5655563           US          NY           100      f
# 9    5655489           US         NaN           024      f
# 10   5655472           US          MA           012      f
# 11   5655472           US          NY           104      f
# 12   5655374           US          MD           209      f
# 13   5655310           US          MA           024      f
# 14   5655184           US          TX           787      m
# 15   5655182           US          CA           940      f
# 16   5655157           US          CA           904      m
# 17   5655125           IL           D           NaN      m
# 18   5655072           US         NaN           104    NaN
# 19   5655026          NaN         NaN           NaN      f
# 20   5654956           US          MA           024      m
# 21   5654953           US          NY           100      m
# 22   5654902           US          NY           104      m
# 23   5654816           US          NJ           076      f
# 24   5654709           US         NaN           481      m
# 25   5654673           US          CA           921      m
# 26   5654672           US         NaN           618      m
# 27   5654630           US          NY           106      f
# 28   5654561           US          CA           900      m
# 29   5654399           US          MA           015      f
# 30   5654321           US          NJ           085      f
# 31   5653991           US          MA           012      m
# 32   5653975           US          CA           940      m
# 33   5653924           US          MA           025      f
# 0                    NaN                NaN
# 1                    NaN                NaN
# 2    personally required                NaN
# 3                    NaN                NaN
# 4                    NaN                NaN
# 5     general quarantine  still quarantined
# 6              voluntary  still quarantined
# 7                    NaN                NaN
# 8     general quarantine  still quarantined
# 9                    NaN                NaN
# 10                   NaN                NaN
# 11             voluntary  still quarantined
# 12                   NaN                NaN
# 13    general quarantine  still quarantined
# 14                   NaN                NaN
# 15                   NaN                NaN
# 16    general quarantine  still quarantined
# 17                   NaN                NaN
# 18                   NaN                NaN
# 19                   NaN                NaN
# 20                   NaN                NaN
# 21    general quarantine  still quarantined
# 22             voluntary  still quarantined
# 23                   NaN                NaN
# 24                   NaN                NaN
# 25    general quarantine  still quarantined
# 26                   NaN                NaN
# 27                   NaN                NaN
# 28                   NaN                NaN
# 29    general quarantine  still quarantined
# 30                   NaN                NaN
# 31             voluntary  still quarantined
# 32    general quarantine  still quarantined
# 33             voluntary  still quarantined
# 34             voluntary  still quarantined
# 35                   NaN                NaN
# 36             voluntary  still quarantined
# 37    general quarantine  still quarantined
# 38             voluntary  still quarantined
# 39                   NaN                NaN
# 40                   NaN                NaN
# 41                   NaN                NaN
# 42    general quarantine                NaN
# 43                   NaN                NaN
# 44                   NaN                NaN
# 45             voluntary                NaN
# 46                   NaN                NaN
# 47                   NaN                NaN
# 48    general quarantine  still quarantined
# 49    general quarantine                NaN
# 50    general quarantine  still quarantined
# 51    general quarantine  still quarantined
# 52                   NaN                NaN
# 53    general quarantine  still quarantined
# 54                   NaN                NaN
# 55                   NaN                NaN
# 56    general quarantine  still quarantined
# 57                   NaN                NaN
# 58                   NaN                NaN
# 59                   NaN                NaN
# 60             voluntary  still quarantined
# 61                   NaN                NaN
# 62                   NaN                NaN
# 63    general quarantine  still quarantined
# 64    general quarantine  still quarantined
# 65                   NaN                NaN
# 66                   NaN                NaN
# 67                   NaN                NaN
# 68             voluntary  still quarantined
# 69                   NaN                NaN
# 70   personally required  still quarantined
# 71                   NaN                NaN
# 72                   NaN                NaN
# 73             voluntary  still quarantined
# 74                   NaN                NaN
# 75    general quarantine  still quarantined
# 76    general quarantine  still quarantined
# 77                   NaN                NaN
# 78             voluntary  still quarantined
# 79             voluntary  still quarantined
# 80                   NaN                NaN
# 81    general quarantine  still quarantined
# 82             voluntary  still quarantined
# 83             voluntary  still quarantined
# 84                   NaN                NaN
# 85                   NaN                NaN
# 86             voluntary  still quarantined
# 87                   NaN                NaN
# 88             voluntary  still quarantined
# 89             voluntary  still quarantined
# 90                   NaN                NaN
# 91                   NaN                NaN
# 92    general quarantine  still quarantined
# 93                   NaN                NaN
# 94                   NaN                NaN
# 95                   NaN                NaN
# 96             voluntary  still quarantined
# 97    general quarantine  still quarantined
# 98             voluntary  still quarantined
# 99             voluntary                NaN
# 100            voluntary  still quarantined
# 101   general quarantine  still quarantined
# 102   general quarantine  still quarantined
# 103   general quarantine  still quarantined
# 104                  NaN                NaN
# 105      due to symptoms                NaN
# 106                  NaN                NaN
# 107                  NaN                NaN
# 108            voluntary  still quarantined
# 109   general quarantine  still quarantined
# 110                  NaN                NaN
# 111            voluntary  still quarantined
# 112            voluntary  still quarantined
# 113            voluntary  still quarantined
# 114            voluntary  still quarantined
# 115   general quarantine                NaN
# 116                  NaN                NaN
# 117                  NaN                NaN
# 118            voluntary  still quarantined

# %%
"""
rowcnt = 0

#fstr = fs.open_fs('covidData.csv')
#fstr.write('sr,rnd,'+headers.toString()+'\n') # write the header

# 'sr' is serial number, 'rnd' is round number

for rnd in range(fromRound, lastRound):
    toRnd = rnd + batchSize
    if (toRnd > lastRound):
        toRnd = lastRound
        
    txns = getTransactionBatch(rnd, toRnd) # Fetch transactions for these rounds 
    
    print(txns)

    # Write transaction
    for i in range(0,len(txns)):
        # Decode data in Note field
        tx = txns[i]
        noteData = algosdk.decodeObj(tx.note)

        #must have a serial number and data, else continue to next one
        if (noteData.s =='' | noteData.d == ''):
            continue
        line = noteData.s+','+tx.round
        for j in range(0,len(headers)):
            line += ","                 # followed by a comma
            key = headers[j]
            if (noteData.d[key]):       # if a value exists
                line += noteData.d[key] # write it
                
        #fstr.write(line+'\n');
        rowcnt+=1    
    rnd+=batchSize
"""

# %%
# attribute array
headers = [
    '_t',  
    '_v',  

    # general demographic data
    'gc',  # string, country code (see Location Data section below)
    'gr',  # string, region code  (see Location Data section below)
    'gzp', # string, 3-digit zip code (US only)
    'ga',  # integer, age group, if present must be in 1,11,21,31,41,51,56,61,66,71,76,81,85
    'gs',  # string , gender, if present must be 'm','f'

    # symptoms
    'sz',  # integer, is symptomatic, no-answer=0/no=-1/yes=1
    's1',  # boolean, fever
    's2',  # boolean, cough
    's3',  # boolean, difficulty breathing
    's4',  # boolean, fatigue
    's5',  # boolean, sore throat
    'sds', # date, when symptoms started, yyyy-mm-dd
    'sde', # date, when symptoms ended, yyyy-mm-dd
    'sdn', # boolean, still symptomatic

    #tested
    'tz',  # integer, tested, no-answer=0/no=-1/yes=1
    'tt',  # integer, tried to get tested, no=-1, yes=1, yes but was denied=2
    'td',  # date, test date, yyyy-mm-dd
    'tr',  # integer, test results, -1=negative,1=positive,2=waiting for result
    'tl',  #  integer, test location, 1=Dr office/2=Hospital/3=Urgent care/4=Ad-hoc center/5=Other

    # medical care
    'mz',  #  integer, received care, no-answer=0/no=-1/yes=1
    'm1',  #  boolean, doctor's office
    'm2',  #  boolean, walk-in clinic
    'm3',  #  boolean, virtual care
    'm4',  #  boolean, hospital/ER
    'm5',  #  boolean, other
    'mh',  #  integer, hospitalized, no-answer=0/no=-1/yes=1
    'mhs', #  date, when admitted, yyyy-mm-dd
    'mhe', #  date, when discharged, yyyy-mm-dd
    'mhn', #  boolean, still in hospital

    # quarantine
    'qz',  # integer, was quarantined, no-answer=0/no=-1/yes=1
    'q1',  # boolean, due to symptoms
    'q2',  # boolean, voluntarily
    'q3',  # boolean, personally required
    'q4',  # boolean, general quarantine
    'qds', # date, when quarantine started, yyyy-mm-dd
    'qde', # date, when quarantine ended, yyyy-mm-dd
    'qdn', # boolean, still quarantined
    'ql',  # integer, left quarantine temporarily no-answer=0/no=-1/yes=1

    'consent' # boolean' , user's consent, mandatory, must be 'true'
]
