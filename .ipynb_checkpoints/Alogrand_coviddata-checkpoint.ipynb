# %% [markdown]
# # Algorand Covid-19 Project
# # Rahul Zalkikar | rz1567@nyu.edu
#
# ## Source documentation:
# https://github.com/algorandfoundation/IReport-Covid/blob/master/js/retrieveData.js

# %%
import algosdk
import math
import pandas as pd
import numpy as np

# %%
def connect_testnet():
    algod_address_testnet = "https://testnet-algorand.api.purestake.io/ps1"
    port_test = ""
    token_test = {
       "X-API-Key": "B3SU4KcVKi94Jap2VXkK83xx38bsv95K5UZm2lab",
    }

    algod_client_test = algosdk.algod.AlgodClient(port_test, algod_address_testnet, token_test)
    return algod_client_test

# %%
def connect_mainnet():
    algod_address_mainnet = "https://mainnet-algorand.api.purestake.io/ps1"
    port = ""
    purestake_api_key = 'XXXXXXXXX'
    token = {
        'X-API-key' : purestake_api_key,
    }

    algod_client = algosdk.algod.AlgodClient(port, algod_address_mainnet, token) # Initialize the algod client and get the basic parameters
    return algod_client

# if using my own node...
#token = "token from the file algod.token"
#server = "http://127.0.0.1" #localhost
#port = 8081 # default

# %%
def client_check(algod_client):
    try:
        status = algod_client.status()
    except Exception as e:
        print("Failed to get algod status: {}".format(e))

    if status:
        print("algod last round: {}".format(status.get("lastRound")))
        print("algod time since last round: {}".format(status.get("timeSinceLastRound")))
        print("algod catchup: {}".format(status.get("catchupTime")))
        print("algod latest version: {}".format(status.get("lastConsensusVersion")))

    # Retrieve latest block information                                                                                                                                               
    last_round = algod_client.status().get("lastRound")
    print("####################")
    block = algod_client.block_info(last_round)
    print(block)

# %%
#algod_client_test = connect_testnet()
#client_check(algod_client_test)

# %%
algod_client = connect_mainnet()
client_check(algod_client)
# Out:
# algod last round: 5785664
# algod time since last round: 2885469453
# algod catchup: 0
# algod latest version: https://github.com/algorandfoundation/specs/tree/4a9db6a25595c6fd097cf9cc137cc83027787eaa
# ####################
# {'hash': 'T4ZJKZFN7OPRAFQUC3TIL4CDHCXUR3LGDP53AJ2NC5WHHLTWV35A', 'previousBlockHash': 'O7Q3RXUKJW6XOQMHOSOJJ3HHFPGRB24SN2C4BFIH3PF26BMFAGDA', 'seed': 'ZLN6Y5YO6A57PUWQDZI4TY6KOPYLES6G4EWIBETQWT3ACN53DURA', 'proposer': 'OXWIMTRZA5TVPABJF534EBBERJG367OLAB6VFN4RAW5P6CQEMXEX7VVDV4', 'round': 5785664, 'period': 0, 'txnRoot': 'WRS2VL2OQ5LPWBYLNBCZV3MEQ4DACSRDES6IUKHGOWYQERJRWC5A', 'reward': 114116, 'rate': 25999980, 'frac': 2650625200, 'txns': {}, 'timestamp': 1585670298, 'currentProtocol': 'https://github.com/algorandfoundation/specs/tree/4a9db6a25595c6fd097cf9cc137cc83027787eaa', 'nextProtocol': '', 'nextProtocolApprovals': 0, 'nextProtocolVoteBefore': 0, 'nextProtocolSwitchOn': 0, 'upgradePropose': '', 'upgradeApprove': False}

# %%
# For retrieving the real covid data from mainnet

address = "COVIDR5MYE757XMDCFOCS5BXFF4SKD5RTOF4RTA67F47YTJSBR5U7TKBNU"
fromRound = 5646000
maxTxnPerCall = 500 # max transactions in a batch
batchSize = 512 #Read the transactions from the blockchain in 512-block installations

params = algod_client.suggested_params()
print("total rounds:",params['lastRound'] - fromRound)
#lastRound_testing = fromRound + 20*batchSize
#print("testing rounds:",lastRound_testing - fromRound)
# Out:
# total rounds: 139673

# %%
#  A recursive function for getting a batch of transactions, to overcome
# the limitation of maxTxnPerCall transaction per call to the API

def getTransactionBatch(fromRnd, toRnd):
    
    if (fromRnd > toRnd):# sanity check
        return []
    
    txs = algod_client.transactions_by_address(address,fromRnd,toRnd,maxTxnPerCall) 
    # make an API call to get the transactions - 500 at a time
    
    return txs['transactions']
    
    '''
    # If we got all the transactions, just return them
    if (fromRnd == toRnd | len(txs['transactions']) < maxTxnPerCall):
        return txs['transactions']
    
        # FIXME: If a single block contains more than maxTxnPerCall
        # transactions for the target address, the code above will return
        # only maxTxnPerCall of them.
        # This is an unlikely case, and not easy to handle. The only way to
        # handle it is to call algod.block(round#), then go over all the
        # transactions in this block and take only the ones corresponding
        # to the target address.
    
    else: # recursive call to get them in two smaller chunks
        midRnd = math.floor((fromRnd+toRnd) / 2)
        txns1 = getTransactionBatch(fromRnd, midRnd)
        txns2 = getTransactionBatch(midRnd+1, toRnd)
        # return the concatenation of the two chunks
        return txns1.concat(txns2)
    '''

# %%
txns = []
batch_limit = 10
for i in range(0,batch_limit):
    txns.extend(getTransactionBatch(fromRound, params['lastRound'])) # Fetch transactions for these rounds 
print("found {} transactions".format(len(txns)))
# Out:
# found 5000 transactions

# %%
def decode_node_data(transactions):
    
    trans_df = pd.DataFrame()
    
    for i in range(len(transactions)):
        
        tx_dict = transactions[i]
        encoded_note = tx_dict['noteb64']
        
        # FIX - VERY INEFFICENT, BUT WORKS FOR NOW
        decoded_note = algosdk.encoding.msgpack.unpackb(algosdk.encoding.base64.b64decode(encoded_note))
        
        cleaned_note_dict = {h:None for h in headers}
        
        for key,value in decoded_note.items():
            key = key.decode("utf-8")
            if str(key) == "d":
                for k,v in value.items():
                    new_value = ""
                    new_key = ""
                    
                    if "b" in str(v): new_value = str(v)[1:]
                    else: new_value = str(v)
                    if "b" in str(k): new_key = k.decode('utf-8')
                    else: new_key = str(k)
                        
                    if "'" in new_value:
                        new_value = new_value.replace("'", "")
                    cleaned_note_dict[new_key] = str(new_value)
        
        trans_df = trans_df.append(cleaned_note_dict, ignore_index=True)
        
    return trans_df

# %%
# attribute array
headers = [
    '_t',  
    '_v',  

    # general demographic data
    'gc',  # string, country code (see Location Data section below)
    'gr',  # string, region code  (see Location Data section below)
    'gzp', # string, 3-digit zip code (US only)
    'ga',  # integer, age group, if present must be in 1,11,21,31,41,51,56,61,66,71,76,81,85
    'gs',  # string , gender, if present must be 'm','f'

    # symptoms
    'sz',  # integer, is symptomatic, no-answer=0/no=-1/yes=1
    's1',  # boolean, fever
    's2',  # boolean, cough
    's3',  # boolean, difficulty breathing
    's4',  # boolean, fatigue
    's5',  # boolean, sore throat
    'sds', # date, when symptoms started, yyyy-mm-dd
    'sde', # date, when symptoms ended, yyyy-mm-dd
    'sdn', # boolean, still symptomatic

    #tested
    'tz',  # integer, tested, no-answer=0/no=-1/yes=1
    'tt',  # integer, tried to get tested, no=-1, yes=1, yes but was denied=2
    'td',  # date, test date, yyyy-mm-dd
    'tr',  # integer, test results, -1=negative,1=positive,2=waiting for result
    'tl',  #  integer, test location, 1=Dr office/2=Hospital/3=Urgent care/4=Ad-hoc center/5=Other

    # medical care
    'mz',  #  integer, received care, no-answer=0/no=-1/yes=1
    'm1',  #  boolean, doctor's office
    'm2',  #  boolean, walk-in clinic
    'm3',  #  boolean, virtual care
    'm4',  #  boolean, hospital/ER
    'm5',  #  boolean, other
    'mh',  #  integer, hospitalized, no-answer=0/no=-1/yes=1
    'mhs', #  date, when admitted, yyyy-mm-dd
    'mhe', #  date, when discharged, yyyy-mm-dd
    'mhn', #  boolean, still in hospital

    # quarantine
    'qz',  # integer, was quarantined, no-answer=0/no=-1/yes=1
    'q1',  # boolean, due to symptoms
    'q2',  # boolean, voluntarily
    'q3',  # boolean, personally required
    'q4',  # boolean, general quarantine
    'qds', # date, when quarantine started, yyyy-mm-dd
    'qde', # date, when quarantine ended, yyyy-mm-dd
    'qdn', # boolean, still quarantined
    'ql',  # integer, left quarantine temporarily no-answer=0/no=-1/yes=1

    'consent' # boolean' , user's consent, mandatory, must be 'true'
]

cols = ["_t","_v","consent","age_group","country_code","region_code","gender","3_dig_zip",
          "doctors_office","walk_in_clinic","virtual_care","hospital_or_ER","other",
           "hospitalized","when_discharged","still_in_hospital","when_admitted","received_care",
          "symptom_quarantine","voluntary_quarantine","personally_required_quarantine","general_quarantine",
          "when_quarantine_ended","still_in_quarantine","when_quarantine_started","left_quarantine_temporarily","was_quarantined",
          "fever","cough","difficulty_breathing","fatigue","sore_throat","when_symptoms_ended","still_symptomatic","when_symptoms_started","is_symptomatic",
          "test_date","test_location","test_results","tried_to_get_tested","tested"]

print(len(cols)==len(headers))
# Out:
# True

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
data_df = decode_node_data(txns)
data_df.columns = cols
display(data_df.head(50))
# Out:
#         _t _v consent age_group country_code region_code gender 3_dig_zip  \
# 0   report  1    True        30           US          PA      m       190
# 1   report  1    True        40           DE        None      f      None
# 2   report  1    True        20           IT          72      f      None
# 3   report  1    True        55           IT          72      m      None
# 4   report  1    True        20           GB         LAN      m      None
# 5   report  1    True        50           IT        None      f      None
# 6   report  1    True        50           IT        None      f      None
# 7   report  1    True        20           IT          72      m      None
# 8   report  1    True        20           IT          72      f      None
# 9   report  1    True        40           IT          72      m      None
# 10  report  1    True        30           ES        None      m      None
# 11  report  1    True        50           IT          72      m      None
# 12  report  1    True        40           IT          72      f      None
# 13  report  1    True        30           IT          34      m      None
# 14  report  1    True        40           US        None      m       018
# 15  report  1    True        30           US          MD      f       212
# 16  report  1    True        50           US          MA      m       024
# 17  report  1    True        60           FR         GES      m      None
# 18  report  1    True        20           IL          TA      m      None
# 19  report  1    True        30           US          AZ      f       200
# 20  report  1    True        30           US          DC      m       200
# 21  report  1    True        70           US        None      f       110
# 22  report  1    True        20           US          NY      f       100
# 23  report  1    True        30           US        None      m      None
# 24  report  1    True        30           US          NY   None       100
# 25  report  1    True        50           IN          DL      m      None
# 26  report  1    True        70           US          GA      f       306
# 27  report  1    True        40           FR        None      m      None
# 28  report  1    True        40           FR         BRE      m      None
# 29  report  1    True        20           US        None      f       021
# 30  report  1    True        40           US        None      m       212
# 31  report  1    True        30           US          CA      m       945
# 32  report  1    True        60           NL          LI      m      None
# 33  report  1    True        40           RU        None      m      None
# 34  report  1    True        40           US        None      f       021
# 35  report  1    True        65           US          TX      f       762
# 36  report  1    True        20           US          CA      m       904
# 37  report  1    True        20           US          MA      m      None
# 38  report  1    True        20           FR         IDF      f      None
# 39  report  1    True        50           BE         WAL      m      None
# 40  report  1    True        30           CI          01      m      None
# 41  report  1    True        50           SE          AB      f      None
# 42  report  1    True        60           SE          AB      m      None
# 43  report  1    True        55           US          CA      f       947
# 44  report  1    True        20           US        None      m       910
# 45  report  1    True        40           DE          BW      f      None
# 46  report  1    True        70           US          NC      f       272
# 47  report  1    True        50           US          RI      f       028
# 48  report  1    True        60           US          FL      m       346
# 49  report  1    True        55           NL        None      m      None
#
#    doctors_office walk_in_clinic virtual_care hospital_or_ER other  \
# 0            None           None         None           None  None
# 1            None           None         None           None  None
# 2            None           None         None           None  None
# 3            None           None         None           None  None
# 4            None           None         None           None  None
# 5            None           None         None           None  None
# 6            None           None         None           None  None
# 7            None           None         None           None  None
# 8            None           None         None           None  None
# 9            None           None         None           None  None
# 10           None           None         None           None  None
# 11           None           None         None           None  None
# 12           None           None         None           None  None
# 13           None           None         None           None  None
# 14           None           None         None           None  None
# 15           None           None         None           None  None
# 16           None           None         None           None  None
# 17           None           None         None           None  None
# 18           None           None         None           None  None
# 19           None           None         None           None  None
# 20           None           None         None           None  None
# 21           None           None         None           None  None
# 22           None           None         None           None  None
# 23           None           None         None           None  None
# 24           None           None         None           True  None
# 25           None           None         None           None  None
# 26           None           None         None           None  None
# 27           None           None         True           None  None
# 28           None           None         None           None  None
# 29           None           None         None           None  None
# 30           None           None         None           None  None
# 31           None           None         None           None  None
# 32           None           None         None           None  None
# 33           None           None         None           None  None
# 34           None           None         None           None  None
# 35           None           None         None           None  None
# 36           None           None         None           None  None
# 37           None           None         None           None  None
# 38           None           None         None           None  None
# 39           None           None         None           None  None
# 40           None           None         None           None  None
# 41           None           None         None           None  None
# 42           None           None         None           None  None
# 43           None           None         None           None  None
# 44           None           None         None           None  None
# 45           None           None         None           None  None
# 46           None           None         None           None  None
# 47           None           None         True           None  None
# 48           None           None         None           None  None
# 49           None           None         None           None  None
#
#    hospitalized when_discharged still_in_hospital when_admitted received_care  \
# 0          None            None              None          None            -1
# 1          None            None              None          None            -1
# 2          None            None              None          None            -1
# 3          None            None              None          None            -1
# 4          None            None              None          None            -1
# 5          None            None              None          None            -1
# 6          None            None              None          None            -1
# 7          None            None              None          None            -1
# 8          None            None              None          None            -1
# 9          None            None              None          None            -1
# 10         None            None              None          None            -1
# 11         None            None              None          None            -1
# 12         None            None              None          None            -1
# 13         None            None              None          None            -1
# 14         None            None              None          None            -1
# 15         None            None              None          None            -1
# 16         None            None              None          None            -1
# 17         None            None              None          None            -1
# 18         None            None              None          None            -1
# 19         None            None              None          None            -1
# 20         None            None              None          None            -1
# 21         None            None              None          None            -1
# 22         None            None              None          None            -1
# 23         None            None              None          None            -1
# 24            1      2020-03-26              None    2020-03-14             1
# 25         None            None              None          None            -1
# 26         None            None              None          None            -1
# 27         None            None              None          None             1
# 28         None            None              None          None            -1
# 29         None            None              None          None            -1
# 30         None            None              None          None            -1
# 31         None            None              None          None            -1
# 32         None            None              None          None            -1
# 33         None            None              None          None            -1
# 34         None            None              None          None            -1
# 35         None            None              None          None            -1
# 36         None            None              None          None            -1
# 37         None            None              None          None            -1
# 38         None            None              None          None            -1
# 39         None            None              None          None            -1
# 40         None            None              None          None            -1
# 41         None            None              None          None            -1
# 42         None            None              None          None            -1
# 43         None            None              None          None            -1
# 44         None            None              None          None            -1
# 45         None            None              None          None            -1
# 46         None            None              None          None            -1
# 47         None            None              None          None             1
# 48         None            None              None          None            -1
# 49         None            None              None          None            -1
#
#    symptom_quarantine voluntary_quarantine personally_required_quarantine  \
# 0                None                 None                           None
# 1                None                 None                           None
# 2                None                 None                           None
# 3                None                 None                           None
# 4                True                 None                           None
# 5                None                 None                           None
# 6                None                 None                           True
# 7                None                 None                           None
# 8                None                 True                           None
# 9                None                 True                           None
# 10               None                 True                           None
# 11               None                 None                           None
# 12               None                 True                           None
# 13               None                 None                           None
# 14               True                 True                           True
# 15               None                 True                           None
# 16               None                 True                           None
# 17               None                 None                           None
# 18               None                 True                           None
# 19               None                 None                           None
# 20               None                 True                           None
# 21               None                 True                           None
# 22               None                 True                           None
# 23               None                 None                           None
# 24               True                 None                           None
# 25               None                 None                           None
# 26               None                 None                           None
# 27               True                 True                           None
# 28               None                 None                           None
# 29               None                 True                           None
# 30               None                 None                           None
# 31               None                 None                           None
# 32               None                 None                           None
# 33               None                 None                           None
# 34               None                 True                           None
# 35               None                 True                           None
# 36               None                 None                           None
# 37               None                 True                           None
# 38               None                 None                           None
# 39               None                 None                           None
# 40               None                 None                           None
# 41               None                 True                           None
# 42               None                 True                           None
# 43               None                 None                           None
# 44               None                 None                           None
# 45               None                 None                           None
# 46               None                 True                           None
# 47               True                 True                           None
# 48               None                 None                           None
# 49               None                 None                           None
#
#    general_quarantine when_quarantine_ended still_in_quarantine  \
# 0                None                  None                None
# 1                True                  None                True
# 2                None                  None                None
# 3                True                  None                True
# 4                None            2020-03-24                None
# 5                None                  None                None
# 6                None                  None                True
# 7                None                  None                None
# 8                True                  None                True
# 9                True                  None                True
# 10               True                  None                True
# 11               None                  None                None
# 12               True                  None                True
# 13               True                  None                True
# 14               True                  None                True
# 15               None                  None                True
# 16               None                  None                True
# 17               True                  None                True
# 18               None            2020-03-29                None
# 19               True                  None                True
# 20               True                  None                True
# 21               None                  None                True
# 22               True                  None                True
# 23               True                  None                True
# 24               None                  None                True
# 25               None                  None                None
# 26               True                  None                True
# 27               None                  None                True
# 28               True                  None                True
# 29               True                  None                True
# 30               True                  None                True
# 31               True                  None                True
# 32               None                  None                None
# 33               True                  None                True
# 34               None                  None                True
# 35               None                  None                True
# 36               True                  None                True
# 37               None                  None                True
# 38               True                  None                True
# 39               True                  None                True
# 40               None                  None                None
# 41               None                  None                True
# 42               None                  None                True
# 43               True                  None                True
# 44               None                  None                None
# 45               True                  None                True
# 46               None                  None                True
# 47               None            2020-03-25                None
# 48               None                  None                None
# 49               True                  None                True
#
#    when_quarantine_started left_quarantine_temporarily was_quarantined fever  \
# 0                     None                        None              -1  None
# 1               2020-03-21                           1               1  None
# 2                     None                        None              -1  None
# 3               2020-03-16                          -1               1  None
# 4               2020-03-15                          -1               1  None
# 5                     None                        None              -1  None
# 6               2020-03-10                          -1               1  None
# 7                     None                        None              -1  None
# 8               2020-03-04                          -1               1  None
# 9               2020-03-07                           1               1  None
# 10              2020-03-12                          -1               1  None
# 11                    None                        None              -1  None
# 12              2020-03-10                           1               1  None
# 13              2020-03-08                          -1               1  None
# 14                    None                           1               1  True
# 15              2020-03-13                           1               1  None
# 16              2020-03-16                           1               1  None
# 17              2020-03-18                          -1               1  None
# 18              2020-03-21                          -1               1  None
# 19              2020-03-12                          -1               1  None
# 20              2020-03-16                           1               1  None
# 21              2020-03-15                           1               1  None
# 22              2020-03-18                           1               1  None
# 23              2020-03-03                          -1               1  None
# 24              2020-03-07                        None               1  True
# 25                    None                        None              -1  None
# 26              2020-03-20                           1               1  None
# 27              2020-03-16                          -1               1  None
# 28              2020-03-16                           1               1  None
# 29              2020-03-22                           1               1  None
# 30              2020-03-24                           1               1  None
# 31              2020-03-17                          -1               1  None
# 32                    None                        None              -1  None
# 33              2020-03-30                           1               1  None
# 34              2020-03-13                           1               1  None
# 35              2020-03-19                           1               1  None
# 36              2020-03-18                           1               1  None
# 37              2020-03-09                           1               1  None
# 38              2020-03-17                           1               1  None
# 39              2020-03-14                           1               1  None
# 40                    None                        None              -1  None
# 41              2020-03-14                           1               1  None
# 42              2020-03-17                           1               1  None
# 43              2020-03-16                           1               1  None
# 44                    None                        None              -1  None
# 45              2020-03-16                           1               1  None
# 46              2020-03-14                           1               1  None
# 47              2020-03-11                          -1               1  True
# 48                    None                        None              -1  None
# 49              2020-03-15                           1               1  None
#
#    cough difficulty_breathing fatigue sore_throat when_symptoms_ended  \
# 0   None                 None    None        None                None
# 1   None                 None    None        None                None
# 2   None                 None    None        None                None
# 3   None                 None    None        None                None
# 4   True                 True    True        True          2020-03-24
# 5   None                 None    None        None                None
# 6   None                 None    None        None                None
# 7   None                 None    None        None                None
# 8   None                 None    None        None                None
# 9   None                 None    None        None                None
# 10  True                 None    None        True                None
# 11  None                 None    None        None                None
# 12  None                 None    None        None                None
# 13  None                 None    None        None                None
# 14  True                 True    True        True                None
# 15  None                 None    None        None                None
# 16  None                 None    None        None                None
# 17  None                 None    None        None                None
# 18  None                 None    None        None                None
# 19  None                 None    None        None                None
# 20  None                 None    None        None                None
# 21  None                 None    None        None                None
# 22  None                 None    None        None                None
# 23  None                 None    None        None                None
# 24  True                 True    True        True                None
# 25  None                 None    None        None                None
# 26  None                 None    None        None                None
# 27  None                 True    None        True          2020-03-27
# 28  None                 None    None        None                None
# 29  None                 None    None        None                None
# 30  None                 None    None        None                None
# 31  None                 None    None        None                None
# 32  None                 None    None        None                None
# 33  None                 None    None        None                None
# 34  None                 None    None        None                None
# 35  None                 None    None        None                None
# 36  None                 None    None        None                None
# 37  None                 None    None        None                None
# 38  None                 None    None        None                None
# 39  None                 None    None        None                None
# 40  None                 None    None        None                None
# 41  None                 None    None        None                None
# 42  None                 None    None        None                None
# 43  None                 None    None        None                None
# 44  None                 None    None        None                None
# 45  None                 None    None        None                None
# 46  None                 None    None        None                None
# 47  None                 None    True        None          2020-03-25
# 48  None                 None    None        None                None
# 49  None                 None    None        None                None
#
#    still_symptomatic when_symptoms_started is_symptomatic   test_date  \
# 0               None                  None             -1        None
# 1               None                  None             -1        None
# 2               None                  None             -1        None
# 3               None                  None             -1        None
# 4               None            2020-03-13              1        None
# 5               None                  None             -1        None
# 6               None                  None             -1        None
# 7               None                  None             -1        None
# 8               None                  None             -1        None
# 9               None                  None             -1        None
# 10              True            2019-11-01              1        None
# 11              None                  None             -1        None
# 12              None                  None             -1        None
# 13              None                  None             -1        None
# 14              True            2020-03-02              1        None
# 15              None                  None             -1        None
# 16              None                  None             -1        None
# 17              None                  None             -1        None
# 18              None                  None             -1        None
# 19              None                  None             -1        None
# 20              None                  None           None        None
# 21              None                  None             -1        None
# 22              None                  None             -1        None
# 23              None                  None             -1        None
# 24              True            2020-03-02              1  2020-03-10
# 25              None                  None             -1        None
# 26              None                  None             -1        None
# 27              None            2020-03-22              1        None
# 28              None                  None             -1        None
# 29              None                  None             -1        None
# 30              None                  None             -1        None
# 31              None                  None             -1        None
# 32              None                  None             -1        None
# 33              None                  None             -1        None
# 34              None                  None             -1        None
# 35              None                  None             -1        None
# 36              None                  None             -1        None
# 37              None                  None             -1        None
# 38              None                  None             -1        None
# 39              None                  None             -1        None
# 40              None                  None             -1        None
# 41              None                  None             -1        None
# 42              None                  None             -1        None
# 43              None                  None             -1        None
# 44              None                  None             -1        None
# 45              None                  None             -1        None
# 46              None                  None             -1        None
# 47              None            2020-03-11              1        None
# 48              None                  None             -1        None
# 49              None                  None             -1        None
#
#    test_location test_results tried_to_get_tested tested
# 0           None         None                  -1     -1
# 1           None         None                  -1     -1
# 2           None         None                  -1     -1
# 3           None         None                  -1     -1
# 4           None         None                  -1     -1
# 5           None         None                  -1     -1
# 6           None         None                None     -1
# 7           None         None                  -1     -1
# 8           None         None                  -1     -1
# 9           None         None                  -1     -1
# 10          None         None                  -1     -1
# 11          None         None                  -1     -1
# 12          None         None                  -1     -1
# 13          None         None                  -1     -1
# 14          None         None                None     -1
# 15          None         None                  -1     -1
# 16          None         None                  -1     -1
# 17          None         None                  -1     -1
# 18          None         None                  -1     -1
# 19          None         None                  -1     -1
# 20          None         None                  -1     -1
# 21          None         None                  -1     -1
# 22          None         None                  -1     -1
# 23          None         None                  -1     -1
# 24             2            1                None      1
# 25          None         None                  -1     -1
# 26          None         None                  -1     -1
# 27          None         None                  -1     -1
# 28          None         None                  -1     -1
# 29          None         None                  -1     -1
# 30          None         None                None     -1
# 31          None         None                  -1     -1
# 32          None         None                  -1     -1
# 33          None         None                  -1     -1
# 34          None         None                  -1     -1
# 35          None         None                  -1     -1
# 36          None         None                  -1     -1
# 37          None         None                  -1     -1
# 38          None         None                  -1     -1
# 39          None         None                  -1     -1
# 40          None         None                  -1     -1
# 41          None         None                  -1     -1
# 42          None         None                  -1     -1
# 43          None         None                  -1     -1
# 44          None         None                  -1     -1
# 45          None         None                  -1     -1
# 46          None         None                None     -1
# 47          None         None                   2     -1
# 48          None         None                  -1     -1
# 49          None         None                  -1     -1

# %%
data_df.to_csv('covidData.csv',index=False)

# %% [markdown]
# ### BASIC DATA PROCESSING

# %%
data_df = pd.read_csv('covidData.csv')
data_df.head()
# Out:
#        _t  _v  consent  age_group country_code region_code gender  3_dig_zip  \
# 0  report   1     True       30.0           US          PA      m      190.0
# 1  report   1     True       40.0           DE         NaN      f        NaN
# 2  report   1     True       20.0           IT          72      f        NaN
# 3  report   1     True       55.0           IT          72      m        NaN
# 4  report   1     True       20.0           GB         LAN      m        NaN
#
#   doctors_office walk_in_clinic virtual_care hospital_or_ER other  \
# 0            NaN            NaN          NaN            NaN   NaN
# 1            NaN            NaN          NaN            NaN   NaN
# 2            NaN            NaN          NaN            NaN   NaN
# 3            NaN            NaN          NaN            NaN   NaN
# 4            NaN            NaN          NaN            NaN   NaN
#
#    hospitalized when_discharged  still_in_hospital when_admitted  \
# 0           NaN             NaN                NaN           NaN
# 1           NaN             NaN                NaN           NaN
# 2           NaN             NaN                NaN           NaN
# 3           NaN             NaN                NaN           NaN
# 4           NaN             NaN                NaN           NaN
#
#    received_care symptom_quarantine voluntary_quarantine  \
# 0           -1.0                NaN                  NaN
# 1           -1.0                NaN                  NaN
# 2           -1.0                NaN                  NaN
# 3           -1.0                NaN                  NaN
# 4           -1.0               True                  NaN
#
#   personally_required_quarantine general_quarantine when_quarantine_ended  \
# 0                            NaN                NaN                   NaN
# 1                            NaN               True                   NaN
# 2                            NaN                NaN                   NaN
# 3                            NaN               True                   NaN
# 4                            NaN                NaN            2020-03-24
#
#   still_in_quarantine when_quarantine_started  left_quarantine_temporarily  \
# 0                 NaN                     NaN                          NaN
# 1                True              2020-03-21                          1.0
# 2                 NaN                     NaN                          NaN
# 3                True              2020-03-16                         -1.0
# 4                 NaN              2020-03-15                         -1.0
#
#    was_quarantined fever cough difficulty_breathing fatigue sore_throat  \
# 0             -1.0   NaN   NaN                  NaN     NaN         NaN
# 1              1.0   NaN   NaN                  NaN     NaN         NaN
# 2             -1.0   NaN   NaN                  NaN     NaN         NaN
# 3              1.0   NaN   NaN                  NaN     NaN         NaN
# 4              1.0   NaN  True                 True    True        True
#
#   when_symptoms_ended still_symptomatic when_symptoms_started  is_symptomatic  \
# 0                 NaN               NaN                   NaN            -1.0
# 1                 NaN               NaN                   NaN            -1.0
# 2                 NaN               NaN                   NaN            -1.0
# 3                 NaN               NaN                   NaN            -1.0
# 4          2020-03-24               NaN            2020-03-13             1.0
#
#   test_date  test_location  test_results  tried_to_get_tested  tested
# 0       NaN            NaN           NaN                 -1.0    -1.0
# 1       NaN            NaN           NaN                 -1.0    -1.0
# 2       NaN            NaN           NaN                 -1.0    -1.0
# 3       NaN            NaN           NaN                 -1.0    -1.0
# 4       NaN            NaN           NaN                 -1.0    -1.0

# %%
def clean_df(df):
    if (len(list(set(df.consent))) == 1) & (list(set(df.consent))[0] == True):
        print("consent given for all data")
    else:
        print("error")
        
    df = df.drop(['_t','_v','consent'],axis = 1)
    
    bool_cols = ['doctors_office','walk_in_clinic','virtual_care','hospital_or_ER','other','still_in_hospital',
                'symptom_quarantine','voluntary_quarantine','personally_required_quarantine','general_quarantine','still_in_quarantine',
                "fever","cough","difficulty_breathing","fatigue","sore_throat","still_symptomatic"]
                 
    for col in bool_cols:
        df[col]= df[col].replace(True, 1)
        df[col]= df[col].replace(False, 0)
    
    return df

# %%
# use anon 3 digit zipcode to try and impute state abbrevs
def long_lat(df):
    lat_long_df = pd.read_csv(r'C:\Users\rayzc\Downloads\us-zip-code-latitude-and-longitude.csv',sep=';')
    states = []
    match = 0
    for state,area in zip(df.region_code,df['3_dig_zip']):
        region = state
        if (str(region)=='nan') & (str(area)!='nan'):
            for s,z in zip(lat_long_df.State,lat_long_df.Zip):
                if (str(int(area)) in str(int(z))):
                    region = s
                    #print(str(int(area)),'matched with',region)
                    match+=1
                    break
        states.append(region)

    df.insert(3, "state_code", states)
    print("{} US 3-dig-zipcodes w/ missing region codes matched with a state".format(match))
    
    all_nan_inds = df.index[df.iloc[:,6:].isna().all(axis=1)]
    print("Removed {} rows with all nans in feature columns".format(len(all_nan_inds)))
    df = cleaner_data_df.drop(all_nan_inds,axis=0)
    
    
    return df

# %%
cleaner_data_df = clean_df(data_df)
cleaner_data_df = long_lat(cleaner_data_df)
print(cleaner_data_df.shape)
cleaner_data_df.head(10)
# Out:
# consent given for all data
# 710 US 3-dig-zipcodes w/ missing region codes matched with a state
# Removed 20 rows with all nans in feature columns
# (4980, 39)
#    age_group country_code region_code state_code gender  3_dig_zip  \
# 0       30.0           US          PA         PA      m      190.0
# 1       40.0           DE         NaN        NaN      f        NaN
# 2       20.0           IT          72         72      f        NaN
# 3       55.0           IT          72         72      m        NaN
# 4       20.0           GB         LAN        LAN      m        NaN
# 5       50.0           IT         NaN        NaN      f        NaN
# 6       50.0           IT         NaN        NaN      f        NaN
# 7       20.0           IT          72         72      m        NaN
# 8       20.0           IT          72         72      f        NaN
# 9       40.0           IT          72         72      m        NaN
#
#    doctors_office  walk_in_clinic  virtual_care  hospital_or_ER  other  \
# 0             NaN             NaN           NaN             NaN    NaN
# 1             NaN             NaN           NaN             NaN    NaN
# 2             NaN             NaN           NaN             NaN    NaN
# 3             NaN             NaN           NaN             NaN    NaN
# 4             NaN             NaN           NaN             NaN    NaN
# 5             NaN             NaN           NaN             NaN    NaN
# 6             NaN             NaN           NaN             NaN    NaN
# 7             NaN             NaN           NaN             NaN    NaN
# 8             NaN             NaN           NaN             NaN    NaN
# 9             NaN             NaN           NaN             NaN    NaN
#
#    hospitalized when_discharged  still_in_hospital when_admitted  \
# 0           NaN             NaN                NaN           NaN
# 1           NaN             NaN                NaN           NaN
# 2           NaN             NaN                NaN           NaN
# 3           NaN             NaN                NaN           NaN
# 4           NaN             NaN                NaN           NaN
# 5           NaN             NaN                NaN           NaN
# 6           NaN             NaN                NaN           NaN
# 7           NaN             NaN                NaN           NaN
# 8           NaN             NaN                NaN           NaN
# 9           NaN             NaN                NaN           NaN
#
#    received_care  symptom_quarantine  voluntary_quarantine  \
# 0           -1.0                 NaN                   NaN
# 1           -1.0                 NaN                   NaN
# 2           -1.0                 NaN                   NaN
# 3           -1.0                 NaN                   NaN
# 4           -1.0                 1.0                   NaN
# 5           -1.0                 NaN                   NaN
# 6           -1.0                 NaN                   NaN
# 7           -1.0                 NaN                   NaN
# 8           -1.0                 NaN                   1.0
# 9           -1.0                 NaN                   1.0
#
#    personally_required_quarantine  general_quarantine when_quarantine_ended  \
# 0                             NaN                 NaN                   NaN
# 1                             NaN                 1.0                   NaN
# 2                             NaN                 NaN                   NaN
# 3                             NaN                 1.0                   NaN
# 4                             NaN                 NaN            2020-03-24
# 5                             NaN                 NaN                   NaN
# 6                             1.0                 NaN                   NaN
# 7                             NaN                 NaN                   NaN
# 8                             NaN                 1.0                   NaN
# 9                             NaN                 1.0                   NaN
#
#    still_in_quarantine when_quarantine_started  left_quarantine_temporarily  \
# 0                  NaN                     NaN                          NaN
# 1                  1.0              2020-03-21                          1.0
# 2                  NaN                     NaN                          NaN
# 3                  1.0              2020-03-16                         -1.0
# 4                  NaN              2020-03-15                         -1.0
# 5                  NaN                     NaN                          NaN
# 6                  1.0              2020-03-10                         -1.0
# 7                  NaN                     NaN                          NaN
# 8                  1.0              2020-03-04                         -1.0
# 9                  1.0              2020-03-07                          1.0
#
#    was_quarantined  fever  cough  difficulty_breathing  fatigue  sore_throat  \
# 0             -1.0    NaN    NaN                   NaN      NaN          NaN
# 1              1.0    NaN    NaN                   NaN      NaN          NaN
# 2             -1.0    NaN    NaN                   NaN      NaN          NaN
# 3              1.0    NaN    NaN                   NaN      NaN          NaN
# 4              1.0    NaN    1.0                   1.0      1.0          1.0
# 5             -1.0    NaN    NaN                   NaN      NaN          NaN
# 6              1.0    NaN    NaN                   NaN      NaN          NaN
# 7             -1.0    NaN    NaN                   NaN      NaN          NaN
# 8              1.0    NaN    NaN                   NaN      NaN          NaN
# 9              1.0    NaN    NaN                   NaN      NaN          NaN
#
#   when_symptoms_ended  still_symptomatic when_symptoms_started  \
# 0                 NaN                NaN                   NaN
# 1                 NaN                NaN                   NaN
# 2                 NaN                NaN                   NaN
# 3                 NaN                NaN                   NaN
# 4          2020-03-24                NaN            2020-03-13
# 5                 NaN                NaN                   NaN
# 6                 NaN                NaN                   NaN
# 7                 NaN                NaN                   NaN
# 8                 NaN                NaN                   NaN
# 9                 NaN                NaN                   NaN
#
#    is_symptomatic test_date  test_location  test_results  tried_to_get_tested  \
# 0            -1.0       NaN            NaN           NaN                 -1.0
# 1            -1.0       NaN            NaN           NaN                 -1.0
# 2            -1.0       NaN            NaN           NaN                 -1.0
# 3            -1.0       NaN            NaN           NaN                 -1.0
# 4             1.0       NaN            NaN           NaN                 -1.0
# 5            -1.0       NaN            NaN           NaN                 -1.0
# 6            -1.0       NaN            NaN           NaN                  NaN
# 7            -1.0       NaN            NaN           NaN                 -1.0
# 8            -1.0       NaN            NaN           NaN                 -1.0
# 9            -1.0       NaN            NaN           NaN                 -1.0
#
#    tested
# 0    -1.0
# 1    -1.0
# 2    -1.0
# 3    -1.0
# 4    -1.0
# 5    -1.0
# 6    -1.0
# 7    -1.0
# 8    -1.0
# 9    -1.0

# %%
cleaner_data_df.to_csv('cleaner_covidData.csv',index=False)

# %% [markdown]
# ### EXPLORATORY ANALYSIS

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(12,5))
US_quarantinetype_df = cleaner_data_df[cleaner_data_df.country_code == 'US'][['country_code','symptom_quarantine','voluntary_quarantine','personally_required_quarantine','general_quarantine']]
grouped_US_quarantinetype_df = US_quarantinetype_df.groupby('country_code').sum().reset_index(drop=True)
grouped_US_quarantinetype_df.loc[0].plot.bar()
plt.title("US reasons for quarantine")
plt.xticks(rotation=0)
plt.show()
